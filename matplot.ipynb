# %%
#pip install matplotlib
import matplotlib

# %%
print(matplotlib.__version__)
# Out:
# 3.7.1

# %%
import numpy as np
import matplotlib.pyplot as p

# %%
x=np.linspace(1,5,10)# starts from 1 to 5 & creates 10 numbers
y=x**2

# %%
x
# Out:
# array([1.        , 1.44444444, 1.88888889, 2.33333333, 2.77777778,
#        3.22222222, 3.66666667, 4.11111111, 4.55555556, 5.        ])

# %%
y
# Out:
# array([ 1.        ,  2.08641975,  3.56790123,  5.44444444,  7.71604938,
#        10.38271605, 13.44444444, 16.90123457, 20.75308642, 25.        ])

# %%
"""
plots can be created via 2 ways-
Functional Method
Object Oriented Method
"""
# Out:
# '\nplots can be created via 2 ways-\nFunctional Method\nObject Oriented Method\n'

# %%
#functional method
p.plot(x,y)

# %%
#adding labels
p.xlabel("X label")
p.ylabel("y label")
p.title("My First Plot")
p.plot(x,y)

# %%
#creating multiple plots on same canvas.
p.subplot(1,2,1)#no. of rows, no. of col's & plot no.
p.plot(x,y,"b")#plot the first plot, "b stands for blue color"

p.subplot(1,2,2)#no. of rows, no. of col's & plot no.
p.plot(y,x,"y")#plotting the second plot."y stands for yellow color."

# %%
#object oriented approach
fig=p.figure()
axes=fig.add_axes([0.1,0.1,0.8,0.8])
axes.plot(x,y)
axes.set_xlabel("x")
axes.set_ylabel("y")
axes.set_title("Object Oriented Plotting Method")
# Out:
# Text(0.5, 1.0, 'Object Oriented Plotting Method')

# %%
#plotting 2 plots on same canvas using object oriented approach
fig=p.figure()
axes1=fig.add_axes([0.1,0.1,0.8,0.8])
axes2=fig.add_axes([0.2,0.6,0.4,0.2])
axes1.plot(x,y,"y")
axes1.set_title("Smaller Plot")
axes2.plot(x,y,"r")
axes2.set_title("Larger Plot")
# Out:
# Text(0.5, 1.0, 'Larger Plot')

# %%
#creating Subplots Using Object Oriented Approach.
fig,axes = p.subplots(nrows=1,ncols=2)

axes[0].plot(x,y)
axes[0].set_title("First Plot")
axes[1].plot(x,y)
axes[1].set_title("Second Plot")

p.tight_layout()#removes overllaping of plots.

# %% [markdown]
# FigureSize & DPI-Dots Per Inch

# %%
fig=p.figure(figsize=(6,2))
ax=fig.add_axes([0,0,1,1])
ax.plot(x,y)
ax.set_title("Customized Plot Size")
ax.set_xlabel("Width")
ax.set_ylabel("height")
# Out:
# Text(0, 0.5, 'height')

# %%
#same can be done with subplots.
fig,axes=p.subplots(nrows=2,ncols=1, figsize=(7,2))
axes[0].plot(x,y)
axes[1].plot(y,x)
#can set individually title,x,y label.
p.tight_layout()

# %%
#Legend
fig = p.figure()
ax=fig.add_axes([0,0,1,1])
ax.plot(x**2, label="x varible") #label is a legend here
ax.plot(y**3, label="y varible")

ax.legend(loc=10)#add this to use legend

# %% [markdown]
# #### Plot Appearance
# ***
#             customize the plot with color & custom way.

# %%
fig= p.figure()
ax = fig.add_axes([0,0,1,1])
ax.plot(x,y, color="purple", lw=3, alpha=0.5, ls="--", marker="o",
markersize=15, markeredgecolor="yellow", markeredgewidth=5, markerfacecolor="black" ) #can use hexa color codes.

# %%
fig= p.figure()
ax = fig.add_axes([0,0,1,1])
ax.plot(x,y, color="purple", lw=3,  ls="--")
ax.set_xlim([0,2])
ax.set_ylim([0,3])
# Out:
# (0.0, 3.0)
